# %%
import scraper
import pandas as pd
import plotly.express as px

# %%
s = scraper.Scraper()

# %%
s.get_lines()
# Out:
#                         name                 human_name  count
# 0                     kumbet                     Kümbet      5
# 11  yigitler-vefa-konut-toki  Yiğitler-Vefa Konut.-Toki      5
# 3         karsiyaka-esenyurt       Karşıyaka - Esenyurt      4
# 12                   gulyurt                    Gülyurt      4
# 1                 sirinevler                 Şirinevler      3
# 6              aydogan-fatih              Aydoğan Fatih      3
# 4             polis-loj-toki            Polis Loj.-Toki      2
# 18                   gultepe                    Gültepe      2
# 15                   alibaba                    Alibaba      2
# 8                  bulbuller                  Bülbüller      2
# 13     numune-hastanesi-toki      Numune Hastanesi-Toki      2
# 5                toki-3-etap                Toki 3 Etap      1
# 2                yumurtatepe                YumurtaTepe      1
# 10   ticaret-lisesi-esentepe    Ticaret Lisesi-Esentepe      1
# ...

# %%
lines = ["karsiyaka-esenyurt", "polis-loj-toki", "gultepe", "4-eylul-san-toptancilar"]

# %%
for line in lines:
    print(f"{scraper.SITE_ROOT}/hat/{line}")
# Out:
# https://ulasim.sivas.bel.tr/hat/karsiyaka-esenyurt
# https://ulasim.sivas.bel.tr/hat/polis-loj-toki
# https://ulasim.sivas.bel.tr/hat/gultepe
# https://ulasim.sivas.bel.tr/hat/4-eylul-san-toptancilar

# %%
# departures
departures = s.get_live_buses_for_stations(10, lines)
departures
# Out:
#                                          route route_code  station  \
# license_plate
# 58H127                         Esenyurt-Numune        5-C       10
# 58H223         Gültepe-Okullar Böl.-Adliye-Avm       23-A       10
#
#                arrive_time_minutes        lat      long
# license_plate
# 58H127                           3  39.747280  37.02381
# 58H223                           7  39.741055  37.02959

# %%
arrivals = pd.concat([
    s.get_live_buses_for_stations([766, 706, 315], lines),
    s.get_live_buses_for_stations(315, "gultepe")
])
arrivals
# Out:
#                                          route route_code  station  \
# license_plate
# 58H021                    Karşıyaka-Üniversite        4-A      766
# 58H223         Gültepe-Okullar Böl.-Adliye-Avm       23-A      706
# 58H209               POLİS LOJMANLARI/AVM/TOKİ        7-D      315
# 58H223         Gültepe-Okullar Böl.-Adliye-Avm       23-A      315
# 58H244                    Karşıyaka-Üniversite        4-A      315
# 58H223         Gültepe-Okullar Böl.-Adliye-Avm       23-A      315
#
#                arrive_time_minutes        lat       long
# license_plate
# 58H021                          12  39.749348  37.013992
# 58H223                          21  39.741055  37.029590
# 58H209                           9  39.725006  36.966198
# 58H223                          22  39.741055  37.029590
# 58H244                          28  39.705040  36.959953
# 58H223                          22  39.741055  37.029590

# %%
px.scatter_map(departures, lat="lat", lon="long", hover_name="arrive_time_minutes")

# %%
px.scatter_map(arrivals, lat="lat", lon="long", hover_name="arrive_time_minutes")
